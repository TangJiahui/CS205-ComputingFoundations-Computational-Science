# %% [markdown]
# > Jiahui Tang

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Command Used**:
#
# `spark-submit P23_spark.py`

# %% [markdown]
# **Output**:
# ```
# Year,avg(Close)
# 2016,743.4867066984126
# 2012,319.3312970280001
# 2017,921.7808373107566
# 2014,558.270557611111
# 2013,439.26437728571443
# 2009,218.42353286904762
# 2018,1109.197705057143
# 2011,282.6487258015873
# 2015,601.5505467777779
# 2010,266.0809473849206
# ```
