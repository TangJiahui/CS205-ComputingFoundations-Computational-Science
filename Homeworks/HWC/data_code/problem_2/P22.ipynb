# %% [markdown]
# > Jiahui Tang

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# **Command Used**:
#
# `spark-submit P22_spark.py`

# %% [markdown]
# **Output**:
#
# ```
# ('/twiki/bin/edit/Main/Double_bounce_sender?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/NewUserTemplate?rev1=1.3&rev2=1.2', 1)
# ('/mailman/listinfo/hsdivision', 1)
# ('/twiki/bin/view/TWiki/WikiSyntax', 1)
# ('/twiki/bin/view/Main/DCCAndPostFix', 12)
# ('/twiki/bin/oops/TWiki/AppendixFileSystem?template=oopsmore&param1=1.12&param2=1.12', 2)
# ('/twiki/bin/view/Main/PeterThoeny', 1)
# ('/twiki/bin/edit/Main/Header_checks?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/attach/Main/OfficeLocations', 1)
# ('/twiki/bin/view/TWiki/WebTopicEditTemplate', 1)
# ('/twiki/bin/view/Main/WebChanges', 2)
# ('/twiki/bin/edit/Main/Smtpd_etrn_restrictions?topicparent=Main.ConfigurationVariables', 1)
# ('/mailman/listinfo/business', 1)
# ('/twiki/bin/rdiff/Main/WebIndex?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/TWiki/DontNotify', 1)
# ('/twiki/bin/view/Main/TokyoOffice', 1)
# ('/twiki/bin/view/Main/MikeMannix', 2)
# ('/twiki/bin/attach/Main/PostfixCommands', 1)
# ('/robots.txt', 27)
# ('/twiki/bin/rdiff/Know/ReadmeFirst?rev1=1.5&rev2=1.4', 1)
# ('/twiki/bin/view/Main/TWikiGroups?rev=1.2', 1)
# ('/twiki/bin/rdiff/Main/ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/Flush_service_name?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiRegistration', 1)
# ('/twiki/bin/rdiff/Main/NicholasLee', 1)
# ('/twiki/bin/view/Sandbox/WebHome?rev=1.6', 1)
# ('/mailman/listinfo/administration', 3)
# ('/razor.html', 26)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Joris%20*Benschop[^A-Za-z]', 1)
# ('/twiki/bin/oops/TWiki/TextFormattingRules?template=oopsmore&param1=1.37&param2=1.37', 1)
# ('/twiki/bin/edit/TWiki/DefaultPlugin?t=1078688936', 1)
# ('/twiki/bin/search/Main/?scope=topic&regex=on&search=^g', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^d', 1)
# ('/twiki/bin/view/Main/LondonOffice', 1)
# ('/twiki/bin/attach/TWiki/TablePlugin', 1)
# ('/twiki/bin/view/TWiki/ManagingWebs?rev=1.22', 1)
# ('/twiki/bin/statistics/Main', 1)
# ('/twiki/bin/view/TWiki/WikiCulture', 1)
# ('/twiki/bin/edit/Main/WebSearch?t=1078669682', 1)
# ('/twiki/bin/oops/TWiki/ResetPassword?template=oopsmore&param1=1.4&param2=1.4', 1)
# ('/twiki/bin/view/TWiki/ManagingWebs?skin=print', 1)
# ('/twiki/bin/edit/Main/UvscanAndPostFix?topicparent=Main.WebHome', 2)
# ('/twiki/bin/view/TWiki/KlausWriessnegger', 1)
# ('/twiki/bin/view/Main/SpamAssassin', 6)
# ('/twiki/bin/oops/TWiki/RichardDonkin?template=oopsmore&param1=1.2&param2=1.2', 1)
# ('/twiki/bin/rdiff/TWiki/AlWilliams?rev1=1.3&rev2=1.2', 1)
# ('/twiki/bin/rdiff/TWiki/AlWilliams?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/TWiki/SvenDowideit', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Office%20*Locations[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.31', 1)
# ('/twiki/bin/edit/Main/KevinWGagel?t=1078670331', 1)
# ('/twiki/bin/edit/Main/Virtual_mailbox_lock?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/WebPreferences', 2)
# ('/twiki/bin/view/TWiki/WikiWord?rev=1.3', 1)
# ('/twiki/bin/oops/Sandbox/WebChanges', 1)
# ('/twiki/bin/rdiff/Main/TWikiGuest', 1)
# ('/twiki/bin/edit/TWiki/TWikiVariables?t=1078684115', 1)
# ('/pipermail/cncce/2004-January/000001.html', 3)
# ('/pipermail/cncce/2004-January/000002.html', 1)
# ('/twiki/bin/rdiff/TWiki/WikiWord?rev1=1.4&rev2=1.3', 1)
# ('/twiki/bin/edit/Main/TWikiPreferences?topicparent=Main.WebHome', 1)
# ('/pipermail/cncce/2004-January.txt', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Web%20*Statistics[^A-Za-z]', 1)
# ('/twiki/bin/rdiff/TWiki/PeterFokkinga?rev1=1.4&rev2=1.3', 1)
# ('/mailman/listinfo/dentalstudies', 1)
# ('/twiki/bin/view/Main/TWikiGuest', 2)
# ('/twiki/bin/attach/Main/TWikiGroups', 1)
# ('/twiki/bin/rdiff/TWiki/TextFormattingRules?rev1=1.36&rev2=1.35', 1)
# ('/twiki/bin/rdiff/Main/TWikiGroups?rev1=1.3&rev2=1.2', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=.*', 1)
# ('/twiki/bin/edit/Main/Trigger_timeout?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/oops/TWiki/TWikiSite?template=oopsmore&param1=1.21&param2=1.21', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.35', 1)
# ('/twiki/bin/edit/Main/Mydestination?topicparent=Main.ConfigurationVariables', 1)
# ('/mailman/listinfo/fcd', 1)
# ('/twiki/bin/rdiff/Main/WebHome?rev1=1.28&rev2=1.27', 2)
# ('/twiki/bin/edit/Main/Message_size_limit?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiHistory', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^y', 1)
# ('/twiki/bin/edit/Main/Smtpd_history_flush_threshold?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=1.59', 1)
# ('/twiki/bin/edit/Main/Sender_canonical_maps?topicparent=Main.ConfigurationVariables', 1)
# ('/mailman/listinfo/mlc', 1)
# ('/twiki/bin/rdiff/Main/WebChanges', 1)
# ('/twiki/bin/edit/Sandbox/TestTopic5?topicparent=Sandbox.WebHome', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.22', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^j', 1)
# ('/twiki/bin/oops/TWiki/TWikiVariables?template=oopsmore&param1=1.62&param2=1.62', 1)
# ('/twiki/bin/edit/Main/Lmtp_connect_timeout?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^q', 1)
# ('/twiki/bin/view/TWiki/ManagingWebs?rev=1.21', 1)
# ('/twiki/bin/edit/Main/Qmqpd_authorized_clients?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/Header_address_token_limit?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/Syslog_name?topicparent=Main.ConfigurationVariables', 1)
# ('*', 1)
# ('/twiki/bin/oops/TWiki/TWikiHistory?template=oopsmore&param1=1.61&param2=1.61', 1)
# ('/twiki/bin/view/TWiki/HaroldGottschalk', 1)
# ('/twiki/bin/view/TWiki/DefaultPlugin?rev=1.4', 1)
# ('/twiki/bin/oops/TWiki/WelcomeGuest?template=oopsmore&param1=1.20&param2=1.20', 1)
# ('/twiki/bin/rdiff/Main/WebIndex', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiRegistration?rev1=1.10&rev2=1.9', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.21', 1)
# ('/twiki/bin/attach/TWiki/DefaultPlugin', 1)
# ('/twiki/bin/search/Main/?scope=topic&regex=on&search=^p', 1)
# ('/twiki/bin/view/Main/SpamAssassinDeleting', 15)
# ('/twiki/bin/edit/Main/Smtp_pix_workaround_delay_time?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/Berkeley_db_create_buffer_size?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/attach/TWiki/TWikiSite', 1)
# ('/twiki/bin/edit/TWiki/TWikiSite?t=1078681794', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Web%20*Statistics[^A-Za-z]', 1)
# ('/twiki/bin/edit/Main/Defer_transports?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/SearchDoesNotWork', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=TWiki%20*Admin%20*Group[^A-Za-z]', 1)
# ('/twiki/bin/rdiff/TWiki/ChangePassword', 1)
# ('/twiki/bin/rdiff/TWiki/SvenDowideit', 1)
# ('/twiki/bin/rdiff/TWiki/KevinKinnell?rev1=1.5&rev2=1.4', 1)
# ('/twiki/bin/edit/Main/Undisclosed_recipients_header?topicparent=Main.ConfigurationVariables', 1)
# ('/mailman/listinfo/hs_support', 1)
# ('/twiki/bin/view/TWiki/WebTopicList', 1)
# ('/twiki/bin/attach/TWiki/WebPreferences', 1)
# ('/twiki/bin/view/TWiki/TWikiFAQ', 1)
# ('/twiki/bin/oops/TWiki/DefaultPlugin?template=oopsmore&param1=1.5&param2=1.5', 1)
# ('/twiki/bin/rdiff/TWiki/AppendixFileSystem?rev1=1.11&rev2=1.10', 1)
# ('/twiki/bin/rdiff/TWiki/FileAttribute', 1)
# ('/twiki/view/Main/WebHome', 1)
# ('/favicon.ico', 28)
# ('/twiki/', 1)
# ('/twiki/bin/view/Main/WebHome', 41)
# ('/twiki/pub/TWiki/TWikiLogos/twikiRobot46x50.gif', 64)
# ('/twiki/bin/view/Main/TWikiUsers', 2)
# ('/twiki/bin/view/Main/KevinWGagel', 3)
# ('/twiki/bin/edit/TWiki/RichardDonkin?t=1078691832', 1)
# ('/twiki/bin/oops/Main/DCC?template=oopsmore&param1=1.1&param2=1.1', 1)
# ('/twiki/bin/view/TWiki/TWikiUpgradeTo01May2000', 1)
# ('/twiki/bin/edit/Main/Mail_release_date?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/TWikiPlugins?rev=1.19', 1)
# ('/AmavisNew.html', 11)
# ('/twiki/bin/attach/Main/ConfigurationVariables', 1)
# ('/mailman/listinfo/techcomm', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=1.8', 1)
# ('/twiki/bin/edit/Sandbox/TestTopic7?topicparent=Sandbox.WebHome', 1)
# ('/twiki/bin/rdiff/TWiki/WebSearch', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiTopics', 1)
# ('/twiki/bin/rdiff/Main/VishaalGolam', 1)
# ('/twiki/bin/view/Main/TWikiUsers?rev=1.21', 1)
# ('/twiki/bin/edit/Main/Delay_notice_recipient?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WikiNotation', 1)
# ('/twiki/bin/edit/Main/Forward_expansion_filter?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/TestArea?topicparent=Main.WebHome', 1)
# ('/twiki/bin/view/Main/TokyoOffice?rev=1.2', 1)
# ('/twiki/bin/attach/TWiki/WebSearch', 1)
# ('/mailman/listinfo/hs_rcafaculty', 1)
# ('/twiki/bin/view/TWiki/TWikiSkins?skin=print', 1)
# ('/twiki/bin/edit/Main/OfficeLocations?t=1078691049', 1)
# ('/twiki/bin/view/Main/ThanadonSomdee', 1)
# ('/mailman/options/cnc_notice/arobin%40shaw.c', 1)
# ('/icons/mailman.jpg', 37)
# ('/icons/PythonPowered.png', 37)
# ('/icons/gnu-head-tiny.jpg', 37)
# ('/mailman/options/cnc_notice', 2)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.16', 1)
# ('/twiki/bin/edit/Main/Default_delivery_slot_discount?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiHistory?rev1=1.10&rev2=1.9', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Al%20*Williams[^A-Za-z]', 1)
# ('/twiki/bin/edit/Main/Smtpd_banner?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/WebHome?rev=r1.9', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiSkins?rev1=1.10&rev2=1.9', 1)
# ('/twiki/bin/attach/TWiki/AndreaSterbini', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiPlugins?rev1=1.20&rev2=1.19', 1)
# ('/twiki/bin/view/Know/ReadmeFirst?rev=1.4', 1)
# ('/twiki/bin/view/Main/TokyoOffice?rev=r1.3', 1)
# ('/twiki/bin/view/TWiki/AlWilliams?rev=1.1', 1)
# ('/clients.html', 4)
# ('/twiki/bin/view/TWiki/JohnTalintyre', 1)
# ('/twiki/bin/view/TWiki/TWikiDocGraphics', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.24', 1)
# ('/twiki/bin/rdiff/Main/SanJoseOffice', 1)
# ('/twiki/bin/rdiff/Main/WebNotify', 1)
# ('/twiki/bin/view/TWiki/TWikiSiteTools', 1)
# ('/twiki/bin/rdiff/TWiki/RichardDonkin?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Web%20*Preferences[^A-Za-z]', 1)
# ('/twiki/bin/rdiff/TWiki/WebHome', 1)
# ('/twiki/bin/edit/Main/Lmtp_quit_timeout?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WebSiteTools', 1)
# ('/twiki/bin/oops/TWiki/JohnAltstadt', 1)
# ('/twiki/bin/oops/Main/FileAttachment?template=oopsmore&param1=1.3&param2=1.3', 1)
# ('/twiki/bin/edit/Main/Cleanup_service_name?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WikiReferences?skin=print', 1)
# ('/twiki/bin/view/Main/TokyoOffice?rev=1.3', 1)
# ('/twiki/bin/view/Main/PostSuper?rev=r1.1', 1)
# ('/twiki/bin/rdiff/Main/PostQueue', 1)
# ('/twiki/bin/edit/TWiki/TablePlugin?t=1078681446', 1)
# ('/', 47)
# ('/DCC.html', 2)
# ('/twiki/bin/oops/Sandbox/WebHome?template=oopsmore&param1=1.7&param2=1.7', 1)
# ('/twiki/bin/edit/Main/WelcomeGuest?topicparent=Main.WebHome', 1)
# ('/twiki/bin/oops/Main/TWiki', 1)
# ('/twiki/bin/view/TWiki/RichardDonkin?skin=print', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=r1.4', 1)
# ('/twiki/bin/view/TWiki/TWikiRegistration?rev=r1.7', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.26', 1)
# ('/twiki/bin/view/TWiki/GoBox', 1)
# ('/twiki/bin/view/Main/FileAttachment?rev=1.1', 1)
# ('/twiki/bin/attach/TWiki/KevinKinnell', 1)
# ('/twiki/bin/rdiff/TWiki/WikiWikiClones', 1)
# ('/twiki/bin/oops/Main/NicholasLee?template=oopsmore&param1=1.2&param2=1.2', 1)
# ('/twiki/bin/edit/Main/TWikiForms?topicparent=Main.TWikiVariables', 1)
# ('/twiki/bin/rdiff/TWiki/DefaultPlugin', 1)
# ('/mailman/admin/educationadmin', 1)
# ('/mailman/private/hsdivision/', 1)
# ('/mailman/listinfo/artsscience', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^i', 1)
# ('/twiki/bin/rdiff/TWiki/AdrianLynch', 1)
# ('/twiki/bin/view/Main/WelcomeGuest', 1)
# ('/twiki/bin/view/Main/MikeMannix?rev=1.3', 1)
# ('/twiki/bin/edit/TWiki/WikiStyleWord?topicparent=TWiki.TextFormattingFAQ', 1)
# ('/twiki/bin/oops/TWiki/InterWikis', 1)
# ('/twiki/bin/view/TWiki/FormattedSearch?rev=1.8', 1)
# ('/twiki/bin/view/TWiki/TWikiEnhancementRequests?rev=1.3', 1)
# ('/twiki/bin/view/Main/FileAttachment?rev=1.2', 1)
# ('/twiki/bin/edit/TWiki/AppendixFileSystem?t=1078674582', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.33', 1)
# ('/twiki/bin/search/Main/?scope=topic&regex=on&search=^t', 1)
# ('/twiki/bin/oops/TWiki/TWikiPlugins?template=oopsmore&param1=1.21&param2=1.21', 1)
# ('/mailman/private/sswk/', 1)
# ('/mailman/private/business/', 1)
# ('/twiki/bin/edit/TWiki/InterWikis?t=1078696998', 1)
# ('/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.18', 1)
# ('/twiki/bin/search/TWiki/?search=\\\\.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on&limit=200', 1)
# ('/twiki/bin/edit/TWiki/TWikiPages?topicparent=TWiki.WelcomeGuest', 1)
# ('/twiki/bin/view/Main/WebHome?rev=r1.16', 1)
# ('/twiki/bin/rdiff/TWiki/RyanFreebern?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/edit/Main/Smtp_line_length_limit?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/WebStatistics?skin=print', 1)
# ('/mailman/listinfo/webber', 4)
# ('/mailman/admin/mlc', 1)
# ('/mailman/listinfo/jjec', 1)
# ('/mailman/listinfo/deans', 1)
# ('/mailman/listinfo/gisgrad', 1)
# ('/twiki/bin/view/Main/WebNotify', 3)
# ('/twiki/bin/edit/Main/Setgid_group?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/WebChanges?skin=print', 1)
# ('/twiki/bin/oops/TWiki/FileAttachment', 1)
# ('/twiki/bin/view/Main/TWi', 1)
# ('/twiki/bin/rdiff/TWiki/IncludeTopicsAndWebPages', 1)
# ('/twiki/bin/oops/Main/WebChanges?template=oopsmore&param1=1.2&param2=1.2', 1)
# ('/twiki/bin/rdiff/TWiki/InstantEnhancements', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiPreferences?rev1=1.47&rev2=1.46', 1)
# ('/twiki/bin/view/Main/WebHome?rev=r1.24', 1)
# ('/mailman/listinfo/ppwc', 13)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&bookview=on&search=.*', 1)
# ('/twiki/bin/edit/Main/Local_recipient_maps?topicparent=Main.ConfigurationVariables', 1)
# ('/mailman/listinfo', 11)
# ('/twiki/bin/oops/Main/KevinWGage', 1)
# ('/twiki/bin/view/Main/PostfixCmd', 6)
# ('/twiki/bin/view/Main/SpamAssassinAndPostFix', 17)
# ('/twiki/bin/edit/TWiki/NewTopic?topicparent=TWiki.WikiSyntax', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiSite', 1)
# ('/twiki/bin/rdiff/TWiki/SimultaneousEdits', 1)
# ('/twiki/bin/view/Main/NicholasLee?rev=1.2', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=1.9', 1)
# ('/mailman/listinfo/ncbnpfaculty', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Inter%20*Wikis[^A-Za-z]', 1)
# ('/twiki/bin/oops/TWiki/TextFormattingFAQ?template=oopsmore&param1=1.14&param2=1.14', 1)
# ('/twiki/bin/rdiff/Main/WebTopicList', 1)
# ('/ie.htm', 8)
# ('/mailman/private/mlc/', 1)
# ('/twiki/bin/view/TWiki/WikiName', 1)
# ('/twiki/bin/rdiff/Main/WebRss', 1)
# ('/twiki/bin/rdiff/TWiki/SvenDowideit?rev1=1.2&rev2=1.1', 1)
# ('/LateEmail.html', 4)
# ('/twiki/bin/edit/Main/Deliver_lock_attempts?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/Daemon_directory?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/KlausWriessnegger?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/Main/TWikiGuest?rev=1.4', 1)
# ('/twiki/bin/edit/Main/Relayhost?topicparent=Main.ConfigurationVariables', 2)
# ('/twiki/bin/oops/Main/TWi', 1)
# ('/twiki/bin/edit/Main/BookView?topicparent=Main.TWikiVariables', 1)
# ('/twiki/bin/rdiff/TWiki/DeleteOrRenameATopic', 1)
# ('/twiki/bin/view/TWiki/DavidWarman', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.28', 1)
# ('/twiki/bin/rdiff/Main/PeterThoeny', 2)
# ('/twiki/bin/edit/TWiki/SvenDowideit?t=1078710644', 1)
# ('/twiki/bin/edit/Main/RBLsHowTo?t=1078668449', 1)
# ('/twiki/bin/view/Main/SpamAssassinTaggingOnly', 18)
# ('/twiki/bin/view/Main/SideBar', 5)
# ('/twiki/bin/rdiff/TWiki/DefaultPlugin?rev1=1.5&rev2=1.4', 1)
# ('/twiki/bin/view/Main/LinksOfUse', 7)
# ('/twiki/bin/view/Main/RelayGateway', 7)
# ('/twiki/bin/view/Main/PostfixCommands', 11)
# ('/twiki/bin/rdiff/TWiki/TWikiHistory?rev1=1.61&rev2=1.60', 1)
# ('/twiki/bin/view/Main/PostSuper', 7)
# ('/twiki/bin/view/Main/RBLsHowTo', 8)
# ('/twiki/bin/view/Main/ConfigurationVariables', 5)
# ('/twiki/bin/edit/Main/Propagate_unmatched_extensions?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/pub/TWiki/TWikiDocGraphics/help.gif', 5)
# ('/mailman/admin/hs_support', 1)
# ('/twiki/bin/edit/Main/Always_bcc?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.5', 1)
# ('/twiki/bin/rdiff/Main/TWikiGuest?rev1=1.5&rev2=1.4', 1)
# ('/twiki/bin/edit/Main/Delay_warning_time?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/TWiki/KlausWriessnegger?t=1078709735', 1)
# ('/twiki/bin/rdiff/TWiki/StanleyKnutson', 1)
# ('/twiki/bin/view/TWiki/WhatIsWikiWiki', 1)
# ('/twiki/bin/view/Main/WebIndex?rev=1.1', 1)
# ('/mailman/private/hs_support/', 1)
# ('/twiki/bin/attach/Sandbox/WebHome', 1)
# ('/twiki/bin/edit/TWiki/UnchangeableTopicBug?topicparent=TWiki.TWikiHistory', 1)
# ('/twiki/bin/view/Main/SpamAssassinUsingRazorAndDCC', 7)
# ('/twiki/bin/view/Main/Postfix', 1)
# ('/twiki/bin/view/Main/TWikiGuest?skin=print', 1)
# ('/twiki/bin/view/TWiki/SvenDowideit?rev=1.1', 1)
# ('/twiki/bin/edit/Main/Maps_rbl_reject_code?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/2fa', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Web%20*Changes[^A-Za-z]', 1)
# ('/twiki/bin/edit/Main/WebStatistics?t=1078690975', 1)
# ('/twiki/bin/view/Main/RelayGateway?rev=1.3', 1)
# ('/twiki/bin/rdiff/TWiki/KevinKinnell?rev1=1.4&rev2=1.3', 1)
# ('/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.11', 1)
# ('/twiki/bin/view/TWiki/TWikiRegistration?rev=r1.4', 1)
# ('/twiki/bin/edit/TWiki/TWikiCodevTWikiEnhancementRequests?topicparent=TWiki.TWikiHistory', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Peter%20*Fokkinga[^A-Za-z]', 1)
# ('/twiki/bin/attach/Main/WebPreferences', 1)
# ('/mailman/admin/hs_rcafaculty', 1)
# ('/twiki/bin/rdiff/TWiki/WebChanges', 1)
# ('/twiki/bin/view/Main/JorisBenschop?skin=print', 1)
# ('/twiki/bin/edit/TWiki/TestArea?topicparent=TWiki.WelcomeGuest', 1)
# ('/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.6', 1)
# ('/twiki/bin/rdiff/TWiki/HaroldGottschalk?rev1=1.2&rev2=1.1', 1)
# ('/pipermail/techcomm/', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.19', 1)
# ('/twiki/bin/edit/Sandbox/TestTopic2?topicparent=Sandbox.WebHome', 1)
# ('/twiki/bin/attach/TWiki/InterWikis', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiSkins?rev1=1.11&rev2=1.10', 1)
# ('/twiki/bin/rdiff/TWiki/WebNotify', 2)
# ('/twiki/bin/view/TWiki/DontNotify?rev=1.1', 1)
# ('/twiki/bin/edit/Main/Masquerade_classes?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=r1.10', 1)
# ('/twiki/bin/view/TWiki/HaroldGottschalk?rev=1.2', 1)
# ('/twiki/bin/edit/TWiki/TWikiCodevTWikiPlannedFeatures?topicparent=TWiki.TWikiHistory', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=r1.44', 1)
# ('/twiki/bin/view/TWiki/PeterFokkinga?rev=1.2', 1)
# ('/twiki/bin/edit/TWiki/TWikiPlugins?t=1078696313', 1)
# ('/mailman/listinfo/webct', 1)
# ('/mailman/listinfo/faculty', 1)
# ('/_vti_bin/owssvr.dll?UL=1&ACT=4&BUILD=2614&STRMVER=4&CAPREQ=0', 1)
# ('/SpamAssassin.html', 12)
# ('/MSOffice/cltreq.asp?UL=1&ACT=4&BUILD=2614&STRMVER=4&CAPREQ=0', 1)
# ('/mailman/admin/sswk', 1)
# ('/mailman/listinfo/purchasing', 1)
# ('/twiki/bin/edit/Main/Invalid_hostname_reject_code?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/Main/WebPreferences?rev1=1.14&rev2=1.13', 1)
# ('/twiki/bin/rename/TWiki/TWikiHistory', 1)
# ('/twiki/bin/view/TWiki/SearchDoesNotWork?rev=r1.2', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=r1.50', 1)
# ('/twiki/bin/edit/TWiki/RyanFreebern?t=1078701457', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=r1.2', 1)
# ('/twiki/bin/rdiff/TWiki/WebTopicEditTemplate', 1)
# ('/images/image005.jpg', 8)
# ('/images/image004.jpg', 8)
# ('/images/msgops.JPG', 8)
# ('/twiki/bin/edit/Main/Unknown_local_recipient_reject_code?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Web%20*Index[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/ChangePassword?rev=r1.6', 1)
# ('/twiki/bin/edit/TWiki/HaroldGottschalk?t=1078717948', 1)
# ('/twiki/bin/edit/Main/Expand_owner_alias?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/WebIndex?rev=r1.2', 1)
# ('/rfc.html', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=RBLs%20*How%20*To[^A-Za-z]', 1)
# ('/twiki/bin/rdiff/TWiki/WebTopicEditTemplate?rev1=1.5&rev2=1.4', 1)
# ('/twiki/bin/rdiff/Main/SpamAssassin', 1)
# ('/twiki/bin/rdiff/Main/TokyoOffice?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/TWiki/TWikiCategoryTable', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=r1.14', 1)
# ('/twiki/bin/view/Main/DCCGraphs', 4)
# ('/twiki/bin/rdiff/TWiki/TWikiHistory?rev1=1.8&rev2=1.7', 1)
# ('/twiki/bin/view/TWiki/ChangePassword?rev=r1.3', 1)
# ('/twiki/bin/attach/TWiki/HaroldGottschalk', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.15', 1)
# ('/twiki/bin/view/TWiki/TWikiTutorial', 1)
# ('/mailman/private/dentalstudies/', 1)
# ('/cgi-bin/mailgraph2.cgi', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_0_err.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_0.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_1_err.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_1.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_2.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_2_err.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_3.png', 16)
# ('/cgi-bin/mailgraph.cgi/mailgraph_3_err.png', 16)
# ('/dccstats/index.html', 14)
# ('/twiki/bin/edit/Sandbox/TestTopic6?topicparent=Sandbox.WebHome', 1)
# ('/twiki/bin/view/TWiki/TablePlugin?skin=print', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Spam%20*Assassin[^A-Za-z]', 1)
# ('/dccstats/stats-spam.1day.png', 15)
# ('/dccstats/stats-spam-ratio.1week.png', 15)
# ('/dccstats/stats-spam-ratio.1day.png', 15)
# ('/dccstats/stats-spam.1week.png', 15)
# ('/dccstats/stats-hashes.1week.png', 15)
# ('/dccstats/stats-spam.1month.png', 15)
# ('/dccstats/stats-spam-ratio.1month.png', 15)
# ('/dccstats/stats-hashes.1month.png', 15)
# ('/dccstats/stats-spam.1year.png', 15)
# ('/dccstats/stats-spam-ratio.1year.png', 15)
# ('/dccstats/stats-hashes.1year.png', 15)
# ('/twiki/bin/view/TWiki/SearchDoesNotWork?rev=r1.1', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=TWiki%20*FAQ[^A-Za-z]', 1)
# ('/twiki/bin/oops/Know/WinDoze95Crash', 1)
# ('/twiki/bin/view/TWiki/WebSearch?rev=r1.10', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiDownload', 1)
# ('/twiki/bin/view/Main/SideBar?rev=1.1', 1)
# ('/twiki/bin/oops/TWiki/TWikiAccessControl', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiFAQ', 1)
# ('/twiki/bin/edit/TWiki/WebNotification?topicparent=TWiki.TWikiUpgradeTo01May2000', 1)
# ('/twiki/bin/view/Main/TWikiGuest?rev=r1.3', 1)
# ('/twiki/bin/view/TWiki/d43', 1)
# ('/twiki/bin/edit/Main/Export_environment?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/Know/ReadmeFirst?rev1=1.6&rev2=1.5', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Change%20*Password[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/TWikiTopics?rev=r1.4', 1)
# ('/twiki/bin/view/TWiki/WebSearch?rev=r1.9', 1)
# ('/twiki/bin/rename/TWiki/DefaultPlugin', 1)
# ('/twiki/bin/view/Main/TWikiGuest?rev=r1.1', 1)
# ('/twiki/bin/edit/TWiki/TWikiRegistration?t=1078670224', 1)
# ('/twiki/bin/view/Main/TWikiAdminGroup?rev=1.6', 1)
# ('/twiki/bin/rdiff/TWiki/WikiSyntax', 1)
# ('/twiki/bin/oops/TWiki/WikiCulture?template=oopsmore&param1=1.8&param2=1.8', 1)
# ('/twiki/bin/view/TWiki/WikiTopic', 1)
# ('/twiki/bin/rdiff/TWiki/WebPreferences', 1)
# ('/twiki/bin/view/TWiki/WebSearch?skin=print', 1)
# ('/twiki/bin/view/TWiki/TWikiTopics?rev=r1.7', 1)
# ('/twiki/bin/search/Main/SearchResult?scope=text&regex=on&search=Thanadon%20*Somdee[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/TWikiUpgradeTo01May2000?rev=1.3', 1)
# ('/twiki/bin/edit/Main/Max_use?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/rdiff/TWiki/WebRss', 1)
# ('/twiki/bin/rdiff/TWiki/WikiCulture?rev1=1.8&rev2=1.7', 1)
# ('/twiki/bin/edit/Main/Lmtp_mail_timeout?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/Main/TWikiGroups', 2)
# ('/twiki/bin/view/Main/TWikiAdminGroup', 3)
# ('/twiki/bin/edit/Main/TWikiGuest?t=1078713282', 1)
# ('/twiki/bin/rdiff/TWiki/AdminSkillsAssumptions', 1)
# ('/twiki/bin/view/Sandbox/WebHome?rev=r1.3', 1)
# ('/twiki/bin/edit/TWiki/WikiNotation?t=1078726052', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Wiki%20*Notation[^A-Za-z]', 1)
# ('/twiki/bin/oops/TWiki/WikiNotation?template=oopsmore&param1=1.3&param2=1.3', 1)
# ('/mailman/admin/artsscience', 1)
# ('/twiki/bin/search/Main/?scope=topic&regex=on&search=^d', 1)
# ('/twiki/bin/edit/TWiki/TWikiCodevFeatureToDo?topicparent=TWiki.TWikiHistory', 1)
# ('/twiki/bin/rename/TWiki/ResetPassword', 1)
# ('/twiki/bin/edit/Main/Fast_flush_domains?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/SpamAssassin?t=1078709979', 1)
# ('/twiki/bin/view/TWiki/TWikiTopics?rev=r1.10', 1)
# ('/twiki/bin/view/TWiki/FileAttribute?rev=r1.2', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiEnhancementRequests', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Kevin%20*Kinnell[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/FileAttribute?rev=1.2', 1)
# ('/twiki/bin/view/TWiki/WikiNotation?skin=print', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiPlannedFeatures', 1)
# ('/mailman/admin/deans', 1)
# ('/pipermail/webber/', 1)
# ('/twiki/bin/view/Main/PostSuper?rev=1.1', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=1.13', 1)
# ('/twiki/bin/edit/Main/Mailq_path?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WebHome?rev=r1.49', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=r1.49', 1)
# ('/twiki/bin/rdiff/TWiki/TWikiDocGraphics?rev1=1.11&rev2=1.10', 1)
# ('/twiki/bin/view/TWiki/WebHome?rev=r1.47', 1)
# ('/twiki/bin/view/Sandbox/WebStatistics', 1)
# ('/pipermail/gisgrad/', 1)
# ('/mailman/admin/webber', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=1.14', 1)
# ('/twiki/bin/view/TWiki/KevinKinnell?rev=1.4', 1)
# ('/twiki/bin/search/Main/?search=\\\\.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on&limit=800', 1)
# ('/twiki/bin/view/Main/DCC', 3)
# ('/twiki/bin/oops/TWiki/HaroldGottschalk?template=oopsmore&param1=1.3&param2=1.3', 1)
# ('/twiki/bin/edit/Main/PostConf?topicparent=Main.PostfixCommands', 2)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=John%20*Talintyre[^A-Za-z]', 1)
# ('/twiki/bin/view/Main/VerifingGatway', 4)
# ('/twiki/bin/view/Main/Relay_Domains', 3)
# ('/twiki/bin/attach/Main/TWikiGuest', 1)
# ('/twiki/bin/view/Main/NicholasLee?rev=1.1', 1)
# ('/twiki/bin/attach/TWiki/TWikiDocGraphics?filename=pencil.gif&revInfo=1', 1)
# ('/twiki/bin/rdiff/TWiki/WebSiteTools?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=r1.55', 1)
# ('/twiki/bin/attach/Main/SpamAssassinAndPostFix', 1)
# ('/mailman/private/artsscience/', 1)
# ('/twiki/bin/search/TWiki/?scope=topic&regex=on&search=^l', 1)
# ('/twiki/bin/rdiff/Main/RelayGateway?rev1=1.3&rev2=1.2', 1)
# ('/twiki/bin/rdiff/Main/RelayGateway?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/rdiff/TWiki/WikiReferences?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/Main/WebPreferences?rev=r1.9', 1)
# ('/twiki/bin/edit/TWiki/WebSiteTools?t=1078731408', 1)
# ('/twiki/bin/attach/TWiki/TWikiDocGraphics?filename=viewtopic.gif&revInfo=1', 1)
# ('/twiki/bin/view/TWiki/SvenDowideit?rev=r1.1', 1)
# ('/twiki/bin/edit/Main/Ignore_mx_lookup_error?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/oops/Main/DCCAndPostFix?template=oopsmore&param1=1.2&param2=1.2', 1)
# ('/twiki/bin/view/TWiki/TWikiHistory?rev=r1.54', 1)
# ('/twiki/bin/edit/Main/Allow_min_user?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/TWiki/KevinKinnell?t=1078692967', 1)
# ('/pipermail/fcd/', 1)
# ('/mailman/listinfo/mgt-157', 1)
# ('/mailman/admin/fcd', 1)
# ('/mailman/listinfo/cnc_forestry', 1)
# ('/twiki/bin/edit/Main/Strict_8bitmime?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WelcomeGuest?rev=r1.19', 1)
# ('/twiki/bin/view/TWiki/TWikiFAQ?rev=1.11', 1)
# ('/mailman/admin/gisgrad', 1)
# ('/mailman/admin/jjec', 1)
# ('/twiki/bin/oops/TWiki/RyanFreebern?template=oopsmore&param1=1.2&param2=1.2', 1)
# ('/twiki/bin/rdiff/TWiki/WebChangesAlert', 1)
# ('/twiki/bin/rdiff/Sandbox/WebTopicList', 1)
# ('/twiki/bin/edit/Main/Virtual_gid_maps?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/NewUserTemplate?skin=print', 1)
# ('/mailman/admin', 2)
# ('/mailman/admin/ncbnpfaculty', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Web%20*Topic%20*List[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/WebSearch?rev=1.11', 1)
# ('/twiki/bin/view/TWiki/MartinCleaver', 1)
# ('/twiki/bin/view/TWiki/WebIndex', 1)
# ('/twiki/bin/edit/Main/TokyoOffice?t=1078706364', 1)
# ('/twiki/bin/rdiff/Main/SpamAssassinAndPostFix?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/rdiff/TWiki/WhatIsWikiWiki', 1)
# ('/twiki/bin/rdiff/Main/WebChanges?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/rdiff/TWiki/EditDoesNotIncreaseTheRevision', 1)
# ('/twiki/bin/rdiff/TWiki/WebTopicList', 1)
# ('/antivirus.html', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Harold%20*Gottschalk[^A-Za-z]', 1)
# ('/twiki/bin/view/TWiki/TextFormattingRules?rev=r1.37', 1)
# ('/twiki/bin/search/Main/?scope=topic&regex=on&search=^f', 1)
# ('/RBL.html', 5)
# ('/twiki/bin/oops/TWiki/TWikiVariables', 1)
# ('/twiki/bin/oops/Know/PublicSupported', 1)
# ('/twiki/bin/oops/Main/SpamAssassinTaggingOnly', 1)
# ('/twiki/bin/edit/Main/RazorAndPostFix?topicparent=Main.WebHome', 1)
# ('/twiki/bin/view/Main/SanJoseOffice', 2)
# ('/twiki/bin/view/TWiki/WebHome', 2)
# ('/twiki/pub/TWiki/TWikiLogos/twikiRobot131x64.gif', 1)
# ('/twiki/pub/TWiki/TWikiDocGraphics/tip.gif', 1)
# ('/twiki/pub/TWiki/TWikiLogos/twikiRobot88x31.gif', 1)
# ('/twiki/bin/view/Sandbox/WebHome', 3)
# ('/twiki/bin/oops/TWiki/WebChangesAlert', 1)
# ('/twiki/bin/oops/TWiki/InterwikiPlugin', 1)
# ('408', 1)
# ('/mailman', 6)
# ('/rejected.html', 1)
# ('/mailman/admin/ppwc', 12)
# ('/mailman/admin/ppwc/logout', 2)
# ('/twiki/bin/oops/TWiki/RegularExp', 1)
# ('/twiki/bin/oops/TWiki/TablePlugin', 1)
# ('/mailman/admin/webct', 1)
# ('/mailman/listinfo/cnc_notice', 1)
# ('/twiki/bin/oops/Main/ThanadonSomdee', 1)
# ('/twiki/bin/oops/Know/TopicClassification', 1)
# ('/twiki/bin/oops/TWiki/TextFormattingRules', 1)
# ('/twiki/bin/oops/Main/TWikiUsers', 1)
# ('/mailman/listinfo/cncce', 2)
# ('/mailman/listinfo/fnac', 1)
# ('/twiki/bin/oops/TWiki/MoveTopic', 1)
# ('/twiki/bin/view/Know/WebStatistics', 1)
# ('/mailman/admin/ppwc/members', 4)
# ('/mailman/admin/ppwc/members?letter=n', 1)
# ('/mailman/admin/ppwc/members?letter=p', 6)
# ('/mailman/admin/ppwc/passwords', 1)
# ('/mailman/admin/ppwc/gateway', 2)
# ('/mailman/admin/ppwc/general', 2)
# ('/mailman/admin/ppwc/?VARHELP=general/owner', 1)
# ('/mailman/options/ppwc/ppwctwentynine--at--shaw.com', 1)
# ('/mailman/options/ppwc/ppwctwentynine@shaw.com', 1)
# ('/mailman/admin/ppwc/members/add', 2)
# ('/mailman/admin/ppwc/members/list', 1)
# ('/twiki/bin/oops/TWiki/WikiTopic', 1)
# ('/twiki/bin/oops/Main/T', 1)
# ('/twiki/bin/oops/TWiki/NicholasLee', 1)
# ('/pipermail/cnc_notice/2004-February.txt', 1)
# ('/pipermail/cnc_notice/2003-December.txt', 1)
# ('/pipermail/cnc_notice/2003-December/000002.html', 1)
# ('/twiki/bin/view/Main/VishaalGolam', 1)
# ('/twiki/bin/oops/TWiki/Wik', 1)
# ('/twiki/bin/view/Know/WebHome', 2)
# ('/twiki/bin/oops/Main/WebStatistics', 1)
# ('/twiki/bin/oops/TWiki/SvenDowideit', 1)
# ('/twiki/bin/oops/Know/WebStatistics', 1)
# ('/twiki/bin/view/Main/SimonMudd', 1)
# ('/pipermail/cipg/2003-november.txt', 1)
# ('/twiki/bin/view/Main/PostQueue', 1)
# ('/twiki/bin/oops/Sandbox/WebStatistics', 1)
# ('/M83A', 1)
# ('/mailman/admindb/ppwc', 3)
# ('/twiki/bin/view/TWiki/WebStatistics', 1)
# ('/twiki/bin/view/Main/WebHome?rev=1.25', 1)
# ('/twiki/bin/view/Main/WebNotify?rev=r1.6', 1)
# ('/twiki/bin/rdiff/TWiki/ManagingTopics?rev1=1.16&rev2=1.15', 1)
# ('/twiki/bin/view/Main/WebHome?rev=r1.8', 1)
# ('/twiki/bin/edit/Main/Max_idle?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/search/TWiki/SearchResult?scope=text&regex=on&search=Appendix%20*File%20*System%5B%5EA-Za-z%5D', 1)
# ('/twiki/bin/view/TWiki/WebTopicViewTemplate', 1)
# ('/twiki/bin/rdiff/Main/WebHome', 1)
# ('/twiki/bin/view/TWiki/WebPreferences?rev=r1.9', 1)
# ('/twiki/bin/rdiff/Main/ConfigurationVariables?rev1=1.2&rev2=1.1', 1)
# ('/twiki/bin/view/Main/AndreaSterbini', 1)
# ('/twiki/bin/rdiff/Main/AndreaSterbini', 1)
# ('/twiki/bin/view/Main/WebHome?skin=print', 1)
# ('/twiki/bin/search/Main/SearchResult?search=%5C.*&scope=topic&order=modified&reverse=on&regex=on&nosearch=on', 1)
# ('/twiki/bin/view/TWiki/FormattedSearch', 1)
# ('/twiki/bin/oops/Main/WebHome?template=oopsmore&param1=1.28&param2=1.8', 1)
# ('/twiki/bin/edit/TWiki/TextFormattingFAQ?t=1075982736', 1)
# ('/twiki/bin/edit/Main/Allow_untrusted_routing?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/edit/Main/Smtp_data_init_timeout?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/AppendixFileSystem?rev=1.10', 1)
# ('/twiki/bin/view/Main/AndreaSterbini?rev=r1.1', 1)
# ('/twiki/bin/view/Know/WebNotify', 1)
# ('/twiki/bin/view/Main/WebHome?skin=print&rev=1.25', 1)
# ('/twiki/bin/edit/Main/Unknown_virtual_mailbox_reject_code?topicparent=Main.ConfigurationVariables', 1)
# ('/twiki/bin/view/TWiki/WebPreferences', 1)
# ('/twiki/bin/oops/Main/WebHome?template=oopsmore&param1=1.28&param2=1.28', 1)
# ('/twiki/bin/view/Main/WebTopicList', 2)
# ('/twiki/bin/view/Main/WebHome?rev=1.27', 1)
# ('/pipermail/webber/2004-January/000000.html', 1)
# ('/twiki/bin/view/Main/WebSearch', 1)
# ('/twiki/bin/view/Sandbox/WebChanges', 1)
# ('/twiki/bin/view/Sandbox/WebPreferences', 1)
# ('/twiki/bin/view/Main/WebStatistics', 1)
# ('/twiki/bin/oops/TWiki/WikiWikiClones', 1)
# ('/twiki/bin/oops/TWiki/1000', 1)
# ('/twiki/bin/oops/Main/Smtpd_recipient_limit', 1)
# ('/dccstats/', 2)
# ('/twiki/bin/oops/TWiki/TWikiPlannedFeatures', 1)
# ('/twiki/bin/view/Sandbox/WebIndex', 1)
# ('/twiki/bin/oops/TWiki/Mana', 1)
# ('/twiki/bin/oops/Main/Mi', 1)
#
# ```
